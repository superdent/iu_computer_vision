# %% [markdown]
# # Verkehrszeichenerkennung in Dashcam-Videos
# Dieses Notebook lädt ein Eingangs-Video, erkennt Verkehrszeichen mit einem vortrainierten YOLOv5-Modell und erstellt ein Ausgangsvideo mit eingeblendeten Schildernamen.
#
# ## Schritte:
# 1. Imports und Setup
# 2. Video laden
# 3. Modell laden
# 4. Erkennung und Untertitelung
# 5. Ausgabevideo speichern

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: boto3==1.34.59 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from -r requirements.txt (line 1)) (1.34.59)
# Requirement already satisfied: opencv-python==4.8.1.78 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from -r requirements.txt (line 2)) (4.8.1.78)
# Requirement already satisfied: torch==2.2.1 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from -r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: matplotlib==3.8.4 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from -r requirements.txt (line 4)) (3.8.4)
# Requirement already satisfied: numpy<2 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from -r requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: botocore<1.35.0,>=1.34.59 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from boto3==1.34.59->-r requirements.txt (line 1)) (1.34.162)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from boto3==1.34.59->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from boto3==1.34.59->-r requirements.txt (line 1)) (0.10.4)
# Requirement already satisfied: filelock in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from torch==2.2.1->-r requirements.txt (line 3)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from torch==2.2.1->-r requirements.txt (line 3)) (4.13.2)
# Requirement already satisfied: sympy in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from torch==2.2.1->-r requirements.txt (line 3)) (1.13.3)
# Requirement already satisfied: networkx in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from torch==2.2.1->-r requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: jinja2 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from torch==2.2.1->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from torch==2.2.1->-r requirements.txt (line 3)) (2025.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from matplotlib==3.8.4->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from matplotlib==3.8.4->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from matplotlib==3.8.4->-r requirements.txt (line 4)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from matplotlib==3.8.4->-r requirements.txt (line 4)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from matplotlib==3.8.4->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from matplotlib==3.8.4->-r requirements.txt (line 4)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from matplotlib==3.8.4->-r requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from matplotlib==3.8.4->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from botocore<1.35.0,>=1.34.59->boto3==1.34.59->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: six>=1.5 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.8.4->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from jinja2->torch==2.2.1->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\develop\python\pycharmprojects\iu_computer_vision\venv\lib\site-packages (from sympy->torch==2.2.1->-r requirements.txt (line 3)) (1.3.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import boto3
import cv2
import torch
import matplotlib.pyplot as plt

# %%
video_path = 'input_videos/cv_regen_1_niedrige_qualität.mp4'
cap = cv2.VideoCapture(video_path)

# %%
if not cap.isOpened():
    print("Fehler: Video konnte nicht geöffnet werden.")
else:
    print("Video erfolgreich geöffnet.")
# Out:
# Video erfolgreich geöffnet.

# %%
ret, frame = cap.read()
if not ret:
    print("Kein Frame gelesen.")
else:
    print("Frame gelesen:", frame.shape)
# Out:
# Frame gelesen: (720, 1280, 3)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    frame_count += 1

print("Anzahl Frames:", frame_count)
cap.release()
# Out:
# Anzahl Frames: 15184
