# %%
from google.colab import drive
import shutil
import zipfile
import os

# Google Drive einbinden
drive.mount('/content/drive')

# Pfade definieren
src_zip = '/content/drive/MyDrive/gtsrb/yolo_training.zip'
dst_dir = '/content'

# Zielverzeichnis erstellen (falls nicht vorhanden)
os.makedirs(dst_dir, exist_ok=True)

# ZIP entpacken
with zipfile.ZipFile(src_zip, 'r') as zip_ref:
    zip_ref.extractall(dst_dir)

print("Datei erfolgreich entpackt nach:", dst_dir)
# Out:
# Mounted at /content/drive
# Datei erfolgreich entpackt nach: /content

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.7 MB/s eta 0:00:00
# ...

# %%
# %%bash
# set -euo pipefail
# chmod +x /content/drive/MyDrive/develop/iu_computer_vision/training/scripts/train_colab_v8.sh
#
# /content/drive/MyDrive/develop/iu_computer_vision/training/scripts/train_colab_v8.sh
# Out:
# /content/drive/MyDrive/develop/iu_computer_vision/training
# Overriding /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/default.yaml with /content/drive/MyDrive/develop/iu_computer_vision/training/configs/yolov8_colab.yaml
# Ultralytics 8.3.207 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
