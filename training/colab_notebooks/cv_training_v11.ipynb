# %%
from google.colab import drive
import shutil
import zipfile
import os

# Google Drive einbinden
drive.mount('/content/drive')

# Pfade definieren
src_zip = '/content/drive/MyDrive/develop/iu_computer_vision/training/datasets/gtsrb/yolo_cls.zip'
dst_dir = '/content'

# Zielverzeichnis erstellen (falls nicht vorhanden)
os.makedirs(dst_dir, exist_ok=True)

# ZIP entpacken
with zipfile.ZipFile(src_zip, 'r') as zip_ref:
    zip_ref.extractall(dst_dir)

print("Datei erfolgreich entpackt nach:", dst_dir)
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-944172922.py in <cell line: 0>()
#      15
#      16 # ZIP entpacken
# ---> 17 with zipfile.ZipFile(src_zip, 'r') as zip_ref:
#      18     zip_ref.extractall(dst_dir)
#      19
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1350             while True:
#    1351                 try:
# -> 1352                     self.fp = io.open(file, filemode)
#    1353                 except OSError:
#    1354                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/develop/iu_computer_vision/training/datasets/gtsrb/yolo_cls.zip'

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.1 MB/s eta 0:00:00
# ...

# %%
# %%bash
# set -euo pipefail
# chmod +x /content/drive/MyDrive/develop/iu_computer_vision/training/scripts/train_colab_v11.sh
#
# /content/drive/MyDrive/develop/iu_computer_vision/training/scripts/train_colab_v11.sh
# Out:
# /content/drive/MyDrive/develop/iu_computer_vision/training
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Overriding /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/default.yaml with /content/drive/MyDrive/develop/iu_computer_vision/training/configs/yolov11_colab.yaml
# ...
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
