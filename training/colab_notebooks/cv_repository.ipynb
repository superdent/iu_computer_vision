# %%
# Setup: Drive mounten, SSH-Key laden, Git-Config setzen
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os, subprocess, textwrap, pathlib
os.makedirs(os.path.expanduser("~/.ssh"), exist_ok=True)

# Privaten Schlüssel aus Drive kopieren
src = "/content/drive/MyDrive/ssh/git_googlecolab"  # dein Key
dst = os.path.expanduser("~/.ssh/id_ed25519")
subprocess.run(["/bin/bash","-lc", f"cp '{src}' '{dst}' && chmod 600 '{dst}'"], check=True)

# SSH-Config + known_hosts
cfg = textwrap.dedent("""\
Host github.com
  HostName github.com
  User git
  IdentityFile ~/.ssh/id_ed25519
  IdentitiesOnly yes
""")
pathlib.Path(os.path.expanduser("~/.ssh/config")).write_text(cfg)
subprocess.run(["/bin/bash","-lc","ssh-keyscan github.com >> ~/.ssh/known_hosts"], check=True)

# Git-Commit-Identität
subprocess.run(["git","config","--global","user.name","superdent"], check=True)
subprocess.run(["git","config","--global","user.email","ruediger.schlenter@gmx.de"], check=True)

# !git config --global core.filemode false
# !git config --global core.autocrlf input
# !git config --global safe.directory '*'
# Out:
# Mounted at /content/drive

# %%
# %%bash
# cd /content/drive/MyDrive/develop
# git clone git@github.com:superdent/iu_computer_vision.git
# cd iu_computer_vision
# Out:
# fatal: destination path 'iu_computer_vision' already exists and is not an empty directory.

# %%
# %%bash
# cd /content/drive/MyDrive/develop/iu_computer_vision/
# git config pull.rebase false
# git pull
# Out:
# Updating ff89528..b3c1563
# Fast-forward
#  .gitignore                                         |    10 +-
#  analysis/notebooks/analyze_generated_video.ipynb   |   177 +
#  analysis/notebooks/analyze_video.ipynb             |   331 +
#  analysis/notebooks/detect_signs.ipynb              |   244 +
#  analysis/notebooks/video_mod.ipynb                 |   211 +
#  analysis/requirements/requirements_notebook.txt    |     7 +
#  analysis/requirements/requirements_video_gen.txt   |     3 +
#  analysis/video_gen/generate_video.py               |   121 +
#  training/configs/datav8_gtsdb.yaml                 |     6 +
#  training/configs/yolov11_gtsdb.yaml                |    19 +
#  .../SynsetSignsetGermany/CC-BY-legalcode.txt       |   396 +
#  .../SynsetSignsetGermany/LICENSE.txt               |    29 +
#  training/datasets/gtsdb/FullIJCNN2013/ReadMe.txt   |    85 +
#  training/datasets/gtsdb/FullIJCNN2013/gt.txt       |  1213 ++
# ...

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
# !git -C /content/drive/MyDrive/develop/iu_computer_vision status
# Out:
# Refresh index: 100% (186/186), done.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %%bash
# cd /content/drive/MyDrive/develop/iu_computer_vision/
# git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   .gitignore
# 	modified:   training/configs/yolov11_colab.yaml
# 	new file:   training/runs/v11/colab/v11_colab3/args.yaml
# 	modified:   training/scripts/train_colab_v11.sh

# %%
# %%bash
# cd /content/drive/MyDrive/develop/iu_computer_vision/
# git add -A
# git add .gitignore
# Out:
# ...
# The file will have its original line endings in your working directory

# %%
# %%bash
# cd /content/drive/MyDrive/develop/iu_computer_vision/
# git commit -m "Colab Notebooks"
# Out:
# [main fd13ca9] Colab Notebooks
#  4 files changed, 113 insertions(+), 6 deletions(-)
#  create mode 100644 training/runs/v11/colab/v11_colab3/args.yaml

# %%
# %%bash
# cd /content/drive/MyDrive/develop/iu_computer_vision/
# git push
# Out:
# To github.com:superdent/iu_computer_vision.git
#    b3c1563..fd13ca9  main -> main
